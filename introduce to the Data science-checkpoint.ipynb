# %% [markdown]
# # ssl.py와 JNM를 사용한 과제

# %% [markdown]
# ### 202102829, 산업경영공학과, 이홍규

# %% [markdown]
# ## 1. 기존 ssl.py

# %%
# Node 클래스 정의
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


# LinkedList 클래스 정의
class LinkedList:

    # 초기화 메소드
    def __init__(self):
        dummy = Node("dummy")
        self.head = dummy
        self.tail = dummy

        self.current = None
        self.before = None

        self.num_of_data = 0

    # append 메소드 (insert - 맨 뒤에 노드 추가, tail과 node의 next, 데이터 개수 변경)
    def append(self, data):
        new_node = Node(data)
        self.tail.next = new_node
        self.tail = new_node

        self.num_of_data += 1

    # delete 메소드 (delete - current 노드 삭제, 인접 노드의 current, next 변경, 데이터 개수 변경)
    def delete(self):
        pop_data = self.current.data

        if self.current is self.tail:
            self.tail = self.before

            # 중요 : current가 next가 아닌 before로 변경된다.
            self.before.next = self.current.next
            self.current = self.before 

            self.num_of_data -= 1

            return pop_data

    # first 메소드 (search1 - 맨 앞의 노드 검색, before, current 변경)
    def first(self):
        # 데이터가 없는 경우 첫번째 노드도 없기 때문에 None 리턴
        if self.num_of_data == 0: 
            return None

        self.before = self.head
        self.current = self.head.next

        return self.current.data

    # next 메소드 (search2 - current 노드의 다음 노드 검색, 이전에 first 메소드가 한번은 실행되어야 함)
    def next(self):
        if self.current.next == None:
            return None

        self.before = self.current
        self.current = self.current.next

        return self.current.data

    # size 메소드
    def size(self):
        return self.num_of_data

# %% [markdown]
# ## 2. treaverse_all() - print each node's data from head to tail

# %%
def traverse_all(self):
        current_node = self.head.next
        print("head", end = '')
        for i in range(self.num_of_data):
            print(f"->({current_node.data})", end= '')
            current_node = current_node.next
        print("->null")

# %% [markdown]
# ### 2-1. input the data

# %%
my_list = Linkedlist()
my_list.append(100)
my_list.append(72)
my_list.append(325)

# %% [markdown]
# ### 2-2. Run

# %%
#정상 동작
# Node 클래스 정의
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


# LinkedList 클래스 정의
class LinkedList:

    # 초기화 메소드
    def __init__(self):
        dummy = Node(0) # dummy = Node("dummy")에서 변경됨
        self.head = dummy
        self.tail = dummy

        self.current = None
        self.before = None

        self.num_of_data = 0

    # append 메소드 (insert - 맨 뒤에 노드 추가, tail과 node의 next, 데이터 개수 변경)
    def append(self, data):
        new_node = Node(data)
        self.tail.next = new_node
        self.tail = new_node

        self.num_of_data += 1

    # delete 메소드 (delete - current 노드 삭제, 인접 노드의 current, next 변경, 데이터 개수 변경)
    def delete(self):
        pop_data = self.current.data

        if self.current is self.tail:
            self.tail = self.before

            # 중요 : current가 next가 아닌 before로 변경된다.
            self.before.next = self.current.next
            self.current = self.before 

            self.num_of_data -= 1

            return pop_data

    # first 메소드 (search1 - 맨 앞의 노드 검색, before, current 변경)
    def first(self):
        # 데이터가 없는 경우 첫번째 노드도 없기 때문에 None 리턴
        if self.num_of_data == 0: 
            return None

        self.before = self.head
        self.current = self.head.next

        return self.current.data

    # next 메소드 (search2 - current 노드의 다음 노드 검색, 이전에 first 메소드가 한번은 실행되어야 함)
    def next(self):
        if self.current.next == None:
            return None

        self.before = self.current
        self.current = self.current.next

        return self.current.data

    
    
    # size 메소드
    def size(self):
        return self.num_of_data  
    
    def traverse_all(self):
        current_node = self.head.next
        print("head", end = '')
        for i in range(self.num_of_data):
            print(f"->({current_node.data})", end= '')
            current_node = current_node.next
        print("->null")
    
my_list = LinkedList()
my_list.append(100)
my_list.append(72)
my_list.append(325)
my_list.traverse_all()
# Out:
# head->(100)->(72)->(325)->null

# %% [markdown]
# ## 3. insert_at(position, new_data)

# %%
def insert_at(self, position, new_data):
    if position < 1:
        print("Error")
        return
    
    if position > self.num_of_data:
        self.append(new_data)
        return
    
    new_node = Node(new_data)
    self.current = self.head.next
    self.before = self.head
    
    for i in range(position):
        self.before = self.current
        self.current = self.current.next
    
    self.before.next = new_node
    new_node.next = self.current
    self.num_of_data +=1

# %% [markdown]
# ### 3-1. input the data

# %%
my_list = LinkedList()
my_list.append(100)
my_list.append(72)
my_list.append(325)

my_list.insert_at(1, 30)
my_list.insert_at(3, 70)
my_list.insert_at(9, 1)

# %% [markdown]
# ### 3-2. Run

# %%
# 정상동작
# Node 클래스 정의
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


# LinkedList 클래스 정의
class LinkedList:

    # 초기화 메소드
    def __init__(self):
        dummy = Node(0) # dummy = Node("dummy")에서 변경됨
        self.head = dummy
        self.tail = dummy

        self.current = None
        self.before = None

        self.num_of_data = 0

    # append 메소드 (insert - 맨 뒤에 노드 추가, tail과 node의 next, 데이터 개수 변경)
    def append(self, data):
        new_node = Node(data)
        self.tail.next = new_node
        self.tail = new_node

        self.num_of_data += 1

    # delete 메소드 (delete - current 노드 삭제, 인접 노드의 current, next 변경, 데이터 개수 변경)
    def delete(self):
        pop_data = self.current.data

        if self.current is self.tail:
            self.tail = self.before

            # 중요 : current가 next가 아닌 before로 변경된다.
            self.before.next = self.current.next
            self.current = self.before 

            self.num_of_data -= 1

            return pop_data

    # first 메소드 (search1 - 맨 앞의 노드 검색, before, current 변경)
    def first(self):
        # 데이터가 없는 경우 첫번째 노드도 없기 때문에 None 리턴
        if self.num_of_data == 0: 
            return None

        self.before = self.head
        self.current = self.head.next

        return self.current.data

    # next 메소드 (search2 - current 노드의 다음 노드 검색, 이전에 first 메소드가 한번은 실행되어야 함)
    def next(self):
        if self.current.next == None:
            return None

        self.before = self.current
        self.current = self.current.next

        return self.current.data

    
    
    # size 메소드
    def size(self):
        return self.num_of_data  
    
    def insert_at(self, position, new_data):
        if position <1 :
            print("Error")
            return
        
        if position > self.num_of_data:
            self.append(new_data)
            return

        new_node = Node(new_data)
        self.current = self.head.next
        self.before = self.head

        for i in range(position):
            self.before = self.current
            self.current = self.current.next

        self.before.next = new_node
        new_node.next = self.current

        self.num_of_data += 1
    
    def traverse_all(self):
        current_node = self.head.next
        print("head", end = '')
        for i in range(self.num_of_data):
            print(f"->({current_node.data})", end= '')
            current_node = current_node.next
        print("->null")
        
my_list = LinkedList()
my_list.append(100)
my_list.append(72)
my_list.append(325)

my_list.insert_at(1, 30)
my_list.insert_at(2, 70)
my_list.insert_at(7, 1)

my_list.traverse_all()
# Out:
# head->(100)->(30)->(70)->(72)->(325)->(1)->null

# %% [markdown]
# ## 4. remove(key)

# %%
def remove(self, key):
    self.before = self.head
    self.current = self.head.next
    
    count = 0
    while self.current:
        if self.current.data == key:
            self.before.next = self.current.next
            self.current = self.before.next
            self.num_of_data-= 1
            count +=1
        else:
            self.before = self.current
            self.current = self.current.next
            
    if count > 0 :
        print(f"{count}번째 원소'{key}'를 삭제합니다.")
    else:
        print(f"해당하는 원소가 없습니다.")

# %% [markdown]
# ### 4-1. input the data

# %%
my_list = LinkedList()
my_list.append(100)
my_list.append(72)
my_list.append(325)

my_list.insert_at(1, 30)
my_list.insert_at(3, 70)
my_list.insert_at(9, 1)

my_list.traverse_all()

my_list.remove(30)
my_list.remove(70)
my_list.remove(110)
my_list.traverse_all()

# %% [markdown]
# ### 4-2. Run

# %%
# 정상작동
# Node 클래스 정의
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


# LinkedList 클래스 정의
class LinkedList:

    # 초기화 메소드
    def __init__(self):
        dummy = Node(0) # dummy = Node("dummy")에서 변경됨
        self.head = dummy
        self.tail = dummy

        self.current = None
        self.before = None

        self.num_of_data = 0

    # append 메소드 (insert - 맨 뒤에 노드 추가, tail과 node의 next, 데이터 개수 변경)
    def append(self, data):
        new_node = Node(data)
        self.tail.next = new_node
        self.tail = new_node

        self.num_of_data += 1

    # delete 메소드 (delete - current 노드 삭제, 인접 노드의 current, next 변경, 데이터 개수 변경)
    def delete(self):
        pop_data = self.current.data

        if self.current is self.tail:
            self.tail = self.before

            # 중요 : current가 next가 아닌 before로 변경된다.
            self.before.next = self.current.next
            self.current = self.before 

            self.num_of_data -= 1

            return pop_data

    # first 메소드 (search1 - 맨 앞의 노드 검색, before, current 변경)
    def first(self):
        # 데이터가 없는 경우 첫번째 노드도 없기 때문에 None 리턴
        if self.num_of_data == 0: 
            return None

        self.before = self.head
        self.current = self.head.next

        return self.current.data

    # next 메소드 (search2 - current 노드의 다음 노드 검색, 이전에 first 메소드가 한번은 실행되어야 함)
    def next(self):
        if self.current.next == None:
            return None

        self.before = self.current
        self.current = self.current.next

        return self.current.data

    
    
    # size 메소드
    def size(self):
        return self.num_of_data  
    
    def insert_at(self, position, new_data):
        if position <1 :
            print("Error")
            return
        
        if position > self.num_of_data:
            self.append(new_data)
            return

        new_node = Node(new_data)
        self.current = self.head.next
        self.before = self.head

        for i in range(position):
            self.before = self.current
            self.current = self.current.next

        self.before.next = new_node
        new_node.next = self.current

        self.num_of_data += 1
        
    def remove(self, key):
        self.before = self.head
        self.current = self.head.next
    
        count = 1
        while self.current:
            if self.current.data == key:
                print(f"{count}번째 원소(key)를 삭제합니다.")
                self.before.next = self.current.next

                if self.current == self.tail:
                    self.tail = self.before

                self.current = self.before.next

                self.num_of_data -= 1
                return
            else:
                self.before = self.current
                self.current = self.current.next
                count += 1
            
        
        print(f"해당하는 원소가 없습니다.")        
    
    
    def traverse_all(self):
        current_node = self.head.next
        print("head", end = '')
        for i in range(self.num_of_data):
            print(f"->({current_node.data})", end= '')
            current_node = current_node.next
        print("->null")
        


        
my_list = LinkedList()
my_list.append(100)
my_list.append(72)
my_list.append(325)

my_list.insert_at(1, 30)
my_list.insert_at(3, 70)
my_list.insert_at(9, 1)

my_list.traverse_all()

my_list.remove(30)
my_list.traverse_all()
my_list.remove(325)
my_list.traverse_all()
my_list.remove(110)
my_list.traverse_all()
# Out:
# head->(100)->(30)->(72)->(70)->(325)->(1)->null
# 2번째 원소(key)를 삭제합니다.
# head->(100)->(72)->(70)->(325)->(1)->null
# 4번째 원소(key)를 삭제합니다.
# head->(100)->(72)->(70)->(1)->null
# 해당하는 원소가 없습니다.
# head->(100)->(72)->(70)->(1)->null
